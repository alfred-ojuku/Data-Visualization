# %% [markdown]
# ## The CSV file format

# %%
import csv

filename = 'data/sitka_weather_07-2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    print(header_raw)
    row2 = next(reader)
    print(row2)
# Out:
# ['STATION', 'NAME', 'DATE', 'PRCP', 'TAVG', 'TMAX', 'TMIN']
# ['USW00025333', 'SITKA AIRPORT, AK US', '2018-07-01', '0.25', '', '62', '50']

# %% [markdown]
# ## Printing the headers and their positions

# %%
for index, column_header in enumerate(header_raw):
    print(index, column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 PRCP
# 4 TAVG
# 5 TMAX
# 6 TMIN

# %% [markdown]
# ## Extracting and reading data

# %%
import matplotlib.pyplot as plt
import csv

filename = 'data/sitka_weather_07-2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting the high temperatures
    highs = []
    for row in reader:
        high = int(row[5])
        highs.append(high)

#plot the high temperatures
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(highs, c='red')

#format plot
plt.title("Daily high temperatures, July 2018", fontsize=24)
plt.xlabel('', fontsize=16)
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9804\3356968049.py:14: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from datetime import datetime
f_date = datetime.strptime('18-7-1', '%y-%m-%d')
print(f_date)
# Out:
# 2018-07-01 00:00:00

# %% [markdown]
# ## Plotting dates

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv

filename = 'data/sitka_weather_07-2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting dates and high temperatures
    dates, highs =[], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        dates.append(current_date)
        highs.append(high)
   
#plot the high temperatures
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red')

#format plot
plt.title("Daily high temperatures, July 2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8780\289416144.py:18: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## Plotting a longer timeframe

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv

filename = 'data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting dates and high temperatures
    dates, highs =[], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        dates.append(current_date)
        highs.append(high)
   
#plot the high temperatures
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red')

#format plot
plt.title("Daily high temperatures, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8780\2912876698.py:18: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## Plotting a second Data series (Low temperatures)

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv

filename = 'data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting dates and high temperatures
    dates, highs, lows =[], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        low = int(row[6])
        dates.append(current_date)
        highs.append(high)
        lows.append(low)
   
#plot the high temperatures
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red')
ax.plot(dates, lows, c='blue')

#format plot
plt.title("Daily high and Low temperatures, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8780\1062245709.py:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## Shading the area in the chart

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv

filename = 'data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #automatic indexes
    for index, column_header in enumerate(header_raw):
        if column_header == 'TMAX':
            Tmax_index = index
        if column_header == 'TMIN':
            Tmin_index = index
    #Getting dates and high temperatures
    dates, highs, lows =[], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[Tmax_index])
        low = int(row[Tmin_index])
        dates.append(current_date)
        highs.append(high)
        lows.append(low)
   
#plot the high temperatures
plt.style.use('grayscale')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.5)
ax.plot(dates, lows, c='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

#format plot
plt.title("Daily high and Low temperatures, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim([20,140])
plt.show()

# %% [markdown]
# ## Error Checking

# %%
import csv

filename = 'data/death_valley_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    print(header_raw)
    print(next(reader))
    print(next(reader))
    print(next(reader))
for index, column_header in enumerate(header_raw):
    print(index, column_header)
# Out:
# ['STATION', 'NAME', 'DATE', 'PRCP', 'TMAX', 'TMIN', 'TOBS']
# ['USC00042319', 'DEATH VALLEY, CA US', '1/1/2018', '0', '65', '34', '42']
# ['USC00042319', 'DEATH VALLEY, CA US', '1/2/2018', '0', '61', '38', '46']
# ['USC00042319', 'DEATH VALLEY, CA US', '1/3/2018', '0', '69', '34', '54']
# 0 STATION
# 1 NAME
# 2 DATE
# 3 PRCP
# 4 TMAX
# 5 TMIN
# 6 TOBS

# %% [markdown]
# ## Death valley 2018 data

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import csv

filename = 'data/death_valley_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    print(header_raw)
    #Getting dates and high temperatures
    dates, highs, lows =[], [], []
    #automatic indexes
    for index, column_header in enumerate(header_raw):
        if column_header == 'TMAX':
            Tmax_index = index
        if column_header == 'TMIN':
            Tmin_index = index
    for row in reader:
        current_date = datetime.strptime(row[2], '%m/%d/%Y')
        try:
            high = int(row[Tmax_index])
            low = int(row[Tmin_index])
        except ValueError:
            print(f"Missing data for {current_date}")
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
   
#plot the high temperatures
plt.style.use('classic')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.5)
ax.plot(dates, lows, c='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

#format plot
plt.title("Daily high and Low temperatures for Death Valley, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.savefig("high_lows")
plt.ylim([20,140])
plt.show()
# Out:
# ['STATION', 'NAME', 'DATE', 'PRCP', 'TMAX', 'TMIN', 'TOBS']
# Missing data for 2018-02-18 00:00:00

# %% [markdown]
# ## Try it myself
# Sitka is in a temperate rainforest, so it gets a fair amount of
# rainfall. In the data file sitka_weather_2018_simple.csv is a header called PRCP,
# which represents daily rainfall amounts. Make a visualization focusing on the
# data in this column. You can repeat the exercise for Death Valley if you’re curious
# how little rainfall occurs in a desert.

# %%
import csv
from datetime import datetime
import matplotlib.pyplot as plt

filename = 'data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting data from the file (dates and precipitation values)
    dates, prcps = [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        try:
            prcp = float(row[3])
        except ValueError:
            print(f"Missing the data for {current_date}")
        else:
            dates.append(current_date)
            prcps.append(prcp)

        
#Visualization of the data
fig, ax = plt.subplots()
ax.plot(dates, prcps)

#format plot
plt.title("Daily Precipitation for Sitka, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Precipitation (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
#plt.savefig("sitka_precipitation", dpi=120)

# %%
import csv
from datetime import datetime
import matplotlib.pyplot as plt

filename = 'data/death_valley_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_raw = next(reader)
    #Getting data from the file (dates and precipitation values)
    dates, prcps = [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%m/%d/%Y')
        try:
            prcp = float(row[3])
        except ValueError:
            print(f"Missing the data for {current_date}")
        else:
            dates.append(current_date)
            prcps.append(prcp)

        
#Visualization of the data
fig, ax = plt.subplots()
ax.plot(dates, prcps)

#format plot
plt.title("Daily Precipitation for Death Valley, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Precipitation (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %% [markdown]
# # Mapping global data sets: JSON format
# In this section, I’ll download a data set representing all the earthquakes that have occurred in the world during the previous month. Then I’ll make a map showing the location of these earthquakes and how significant each one was

# %%
import json

#data structure exploration
filename = 'data/eq_data_1_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    
readable_file = 'data/readable_eq_data.json'
with open(readable_file, 'w') as f:
    json.dump(all_eq_data, f, indent=4)

# %% [markdown]
# ## Making a list of all earthquakes

# %%
all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))
# Out:
# 160

# %% [markdown]
# ## Extracting magnitudes

# %%
import json

#data structure exploration
filename = 'data/eq_data_1_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags = []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        mags.append(mag)
# Out:
# [2.2, 1.69, 1.84, 1.5, 1.1]

# %% [markdown]
# ## Extracting Location data
# The location data is stored under the key "geometry". Inside the geometry dictionary is a "coordinates" key, and the first two values in this list are the longitude and latitude.

# %%
import json

#data structure exploration
filename = 'data/eq_data_1_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags, lons, lats = [], [], []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        lon = eq_dict['geometry']['coordinates'][0]
        lat = eq_dict['geometry']['coordinates'][1]
        mags.append(mag)
        lons.append(lon)
        lats.append(lat)
# Out:
# [-147.9414, -121.2621689, -116.0865, -149.3014, -155.3274]
# [64.5058, 36.6464996, 33.2518333, 61.8964, 58.207]

# %% [markdown]
# ## Building a World map

# %%
import json
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

#data structure exploration
filename = 'data/eq_data_1_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags, lons, lats = [], [], []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        lon = eq_dict['geometry']['coordinates'][0]
        lat = eq_dict['geometry']['coordinates'][1]
        mags.append(mag)
        lons.append(lon)
        lats.append(lat)
        
#maps the earthquakes
data = Scattergeo(lon=lons, lat=lats)
my_layout = Layout(title='Global Eartquakes')
fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='Global Earthquakes.html')
# Out:
# 'Global Earthquakes.html'

# %% [markdown]
# ## Customizing maker size
# I'll change the size of the markers depending on the magnitude of the earthquake to communicate severity.

# %%
import json
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

#data structure exploration
filename = 'data/eq_data_1_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags, lons, lats = [], [], []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        lon = eq_dict['geometry']['coordinates'][0]
        lat = eq_dict['geometry']['coordinates'][1]
        mags.append(mag)
        lons.append(lon)
        lats.append(lat)
        
#maps the earthquakes
data = [{
    'type':'scattergeo',
    'lon':lons, 
    'lat':lats,
    'marker':{
        'size':[5*mag for mag in mags]
    }
    
}]
my_layout = Layout(title='Global Eartquakes')
fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='Global Earthquakes.html')
# Out:
# 'Global Earthquakes.html'

# %% [markdown]
# ## Customizing color markers
# I'll customize each marker's color to provide some classification to the severity of the earthquake.
# All significant changes occur in the 'marker' dictionary.

# %%
import json
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

#data structure exploration
filename = 'data/eq_data_30_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags, lons, lats = [], [], []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        lon = eq_dict['geometry']['coordinates'][0]
        lat = eq_dict['geometry']['coordinates'][1]
        mags.append(mag)
        lons.append(lon)
        lats.append(lat)
        
#maps the earthquakes
data = [{
    'type':'scattergeo',
    'lon':lons, 
    'lat':lats,
    'marker':{
        'size':[3*mag for mag in mags],
        'color': mags,
        'colorscale':'Viridis',
        'reversescale': True,
        'colorbar':{'title':'Magnitude'},
    },
    
}]
my_layout = Layout(title='Global Eartquakes')
fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='Global Earthquakes past 30 days.html')
# Out:
# 'Global Earthquakes past 30 days.html'

# %% [markdown]
# ## Other colorscales
# Plotly stores the colorscale in the colors module. The colorscales are defined in dictionary called PLOTLY_SCALES.

# %%
from plotly import colors

for key in colors.PLOTLY_SCALES.keys():
    print(key)
# Out:
# Greys
# YlGnBu
# Greens
# YlOrRd
# Bluered
# RdBu
# Reds
# Blues
# Picnic
# Rainbow
# Portland
# Jet
# Hot
# Blackbody
# Earth
# Electric
# Viridis
# Cividis

# %% [markdown]
# ## Adding Hover text

# %%
import json
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

#data structure exploration
filename = 'data/eq_data_30_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags, lons, lats, hover_text = [], [], [], []
    for eq_dict in all_eq_dicts:
        mag = eq_dict['properties']['mag']
        lon = eq_dict['geometry']['coordinates'][0]
        lat = eq_dict['geometry']['coordinates'][1]
        title = eq_dict['properties']['title']
        mags.append(mag)
        lons.append(lon)
        lats.append(lat)
        hover_text.append(title)
        
#maps the earthquakes
data = [{
    'type':'scattergeo',
    'lon':lons, 
    'lat':lats,
    'text':hover_text,
    'marker':{
        'size':[3*mag for mag in mags],
        'color': mags,
        'colorscale':'Viridis',
        'reversescale': True,
        'colorbar':{'title':'Magnitude'},
    },
    
}]
my_layout = Layout(title='Global Eartquakes')
fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='Global Earthquakes past 30 days.html')
# Out:
# 'Global Earthquakes past 30 days.html'

# %% [markdown]
# ## Try it myself
# The loop that pulls data from all_eq_dicts uses variables for the magnitude, longitude, latitude, and title of each earthquake before appending these values to their appropriate lists. This approach was chosen for clarity in how to pull data from a JSON file, but it’s not necessary in your code. Instead of using these temporary variables, pull each value from eq_dict and
# append it to the appropriate list in one line. Doing so should shorten the body of this loop to just four lines.

# %%
import json
from plotly.graph_objs import Scattergeo, Layout
from plotly import offline

#data structure exploration
filename = 'data/eq_data_30_day_m1.json'
with open(filename, encoding='utf-8') as f:
    all_eq_data = json.load(f)
    all_eq_dicts = all_eq_data['features']
    
    mags = [eq_dict['properties']['mag'] for eq_dict in all_eq_dicts]
    lons = [eq_dict['geometry']['coordinates'][0] for eq_dict in all_eq_dicts]
    lats = [eq_dict['geometry']['coordinates'][1] for eq_dict in all_eq_dicts]
    hover_text = [eq_dict['properties']['title'] for eq_dict in all_eq_dicts]
        
#maps the earthquakes
data = [{
    'type':'scattergeo',
    'lon':lons, 
    'lat':lats,
    'text':hover_text,
    'marker':{
        'size':[3*mag for mag in mags],
        'color': mags,
        'colorscale':'Viridis',
        'reversescale': True,
        'colorbar':{'title':'Magnitude'},
    },
    
}]
chart_title = all_eq_data['metadata']['title']
my_layout = Layout(title=chart_title)
fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='Global Earthquakes past 30 days.html')
# Out:
# 'Global Earthquakes past 30 days.html'

# %% [markdown]
# ### Plotting earlier examples using Pandas

# %%
import pandas as pd

df = pd.read_csv('data/death_valley_2018_simple.csv')
df
# Out:
#          STATION                 NAME        DATE  PRCP  TMAX  TMIN  TOBS
# 0    USC00042319  DEATH VALLEY, CA US    1/1/2018   0.0  65.0  34.0  42.0
# 1    USC00042319  DEATH VALLEY, CA US    1/2/2018   0.0  61.0  38.0  46.0
# 2    USC00042319  DEATH VALLEY, CA US    1/3/2018   0.0  69.0  34.0  54.0
# 3    USC00042319  DEATH VALLEY, CA US    1/4/2018   0.0  69.0  39.0  48.0
# 4    USC00042319  DEATH VALLEY, CA US    1/5/2018   0.0  74.0  40.0  57.0
# ..           ...                  ...         ...   ...   ...   ...   ...
# 359  USC00042319  DEATH VALLEY, CA US  12/27/2018   0.0  68.0  39.0  52.0
# 360  USC00042319  DEATH VALLEY, CA US  12/28/2018   0.0  63.0  48.0  50.0
# 361  USC00042319  DEATH VALLEY, CA US  12/29/2018   0.0  63.0  45.0  46.0
# 362  USC00042319  DEATH VALLEY, CA US  12/30/2018   0.0  63.0  33.0  45.0
# 363  USC00042319  DEATH VALLEY, CA US  12/31/2018   0.0  63.0  38.0  50.0
#
# [364 rows x 7 columns]

# %%
from dateutil.parser import parser
import matplotlib.pyplot as plt
from datetime import datetime

dates = [datetime.strptime(date, '%m/%d/%Y') for date in df['DATE']]
#d = [parser(date) for date in df['DATE']]
prcps = df['PRCP']

#Visualization of the data
fig, ax = plt.subplots()
ax.plot(dates, prcps)

#format plot
plt.title("Daily Precipitation for Death Valley, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Precipitation (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('data/sitka_weather_2018_simple.csv')
df
# Out:
#          STATION                  NAME        DATE  PRCP  TAVG  TMAX  TMIN
# 0    USW00025333  SITKA AIRPORT, AK US  2018-01-01  0.45   NaN    48    38
# 1    USW00025333  SITKA AIRPORT, AK US  2018-01-02  0.56   NaN    48    43
# 2    USW00025333  SITKA AIRPORT, AK US  2018-01-03  0.40   NaN    46    41
# 3    USW00025333  SITKA AIRPORT, AK US  2018-01-04  0.99   NaN    42    40
# 4    USW00025333  SITKA AIRPORT, AK US  2018-01-05  0.25   NaN    46    38
# ..           ...                   ...         ...   ...   ...   ...   ...
# 358  USW00025333  SITKA AIRPORT, AK US  2018-12-27  0.26   NaN    47    42
# 359  USW00025333  SITKA AIRPORT, AK US  2018-12-28  0.03   NaN    44    35
# 360  USW00025333  SITKA AIRPORT, AK US  2018-12-29  0.13   NaN    38    32
# 361  USW00025333  SITKA AIRPORT, AK US  2018-12-30  0.20   NaN    42    36
# 362  USW00025333  SITKA AIRPORT, AK US  2018-12-31  0.89   NaN    48    41
#
# [363 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/sitka_weather_2018_simple.csv')



dates = [datetime.strptime(date, '%Y-%m-%d') for date in df['DATE']] 
prcps = df['PRCP']

#Visualization of the data
fig, ax = plt.subplots()
ax.plot(dates, prcps)

#format plot
plt.title("Daily Precipitation for Sitka, -2018", fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Precipitation (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
#plt.savefig("sitka_precipitation", dpi=120)
